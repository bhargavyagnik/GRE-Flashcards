# %%
import pandas as pd
df = pd.read_csv('vocab.csv',encoding='cp1252')

# %%
df.head()
# Out:
#    Unnamed: 0 Gregmat     Magoosh Manhattan Prep Scholar  Powerscore  \
# 0         1.0   abate    aberrant     abase        abate    abdicate
# 1         2.0    abet  aberration     abate     aberrant    aberrant
# 2         3.0   abhor      abjure  abdicate       abjure    abeyance
# 3         4.0  abjure  aboveboard  aberrant      abscond      abjure
# 4         5.0  abound    abrogate  abeyance      abstain  abstemious
#
#   Vince Kotchian / Brian McElroy Greenlight Basic Greenlight Advanced  \
# 0                          abase            abash              abjure
# 1                        abashed            abate            abrogate
# 2                          abate         aberrant          abscission
# 3                     aberration           abject            acarpous
# 4                       abeyance         abrasive           accession
#
#    Unnamed: 9  ... Unnamed: 15 Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Gregmat', 'Magoosh', 'Manhattan', 'Prep Scholar',
#        'Powerscore', 'Vince Kotchian / Brian McElroy', 'Greenlight Basic',
#        'Greenlight Advanced', 'Unnamed: 9', 'Work', 'Meaning', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %%
s=df[['Gregmat', 'Magoosh', 'Manhattan', 'Prep Scholar',
       'Powerscore', 'Vince Kotchian / Brian McElroy', 'Greenlight Basic',
       'Greenlight Advanced']]

# %%
s
# Out:
#      Gregmat     Magoosh Manhattan Prep Scholar  Powerscore  \
# 0      abate    aberrant     abase        abate    abdicate
# 1       abet  aberration     abate     aberrant    aberrant
# 2      abhor      abjure  abdicate       abjure    abeyance
# 3     abjure  aboveboard  aberrant      abscond      abjure
# 4     abound    abrogate  abeyance      abstain  abstemious
# ...      ...         ...       ...          ...         ...
# 1504     NaN         NaN       NaN          NaN         NaN
# 1505     NaN         NaN       NaN          NaN         NaN
# 1506     NaN         NaN       NaN          NaN         NaN
# 1507     NaN         NaN       NaN          NaN         NaN
# 1508     NaN         NaN       NaN          NaN         NaN
#
#      Vince Kotchian / Brian McElroy Greenlight Basic Greenlight Advanced
# 0                             abase            abash              abjure
# 1                           abashed            abate            abrogate
# ...

# %%
x=s.values.flatten().tolist()

# %%
y=set(x)

# %%
len(y)
# Out:
# 2885

# %%
words=list(y)

# %%
words[1:]
# Out:
# ['retiring',
#  'meander',
#  'superfluous',
#  'bumbling',
#  'flux',
#  'adequate',
#  'improbable',
#  'daunting',
#  'wane',
#  'superficial',
#  'dyspeptic',
#  'tantamount',
#  'concoct',
#  'panned',
#  'cantankerous',
#  'contemptuous',
#  'abase',
#  'gratis',
#  'peregrination',
#  'expedite',
#  'corollary',
#  'cataclysmic',
#  'condone',
#  'contrite',
#  'despotic',
#  'defalcate',
#  'collaborate',
#  'ignominious',
#  'gestation',
#  'manifold',
#  'glancing',
#  'bureaucracy',
#  'competent',
#  'adept',
#  'haggard',
#  'dilatory',
#  'panache',
#  'pied',
#  'optimal',
#  'adroit',
#  'sidereal',
#  'panoply',
#  'regress',
#  'pastiche',
#  'congenial',
#  'probity',
#  'antecedent',
#  'torpid',
#  'sordid',
#  'omission',
#  'enchant',
#  'tantalizing',
#  'wanting',
#  'unearth',
#  'viturperate',
#  'foppish',
#  'obeisance',
#  'luminary',
#  'martial',
#  'disperse',
#  'cow',
#  'landmark',
#  'disposition',
#  'disingenuous',
#  'bludgeon',
#  'renege',
# ...

# %%
cleanedList = [x for x in words if str(x) != 'nan']

# %%
len(cleanedList)
# Out:
# 2884

# %%
from PyDictionary import PyDictionary

dictionary=PyDictionary("hotel","ambush","nonchalant","perceptive")

print(dictionary.printMeanings()) 
print(dictionary.getMeanings())
print (dictionary.getSynonyms())
# Out:
# Error: The Following Error occured: HTTPConnectionPool(host='wordnetweb.princeton.edu', port=80): Max retries exceeded with url: /perl/webwn?s=nonchalant (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000023952ED8438>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# Hotel:
# Noun:
# a building where travelers can pay for lodging and meals and other services
# Ambush:
# Noun:
# the act of concealing yourself and lying in wait to attack by surprise
# Verb:
# wait in hiding to attack
# hunt (quarry
# Nonchalant:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-6ca7c710a66b> in <module>
# ...

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

data=np.array([[1993,127],[173,2707]])
df_cm = pd.DataFrame(data, columns=np.array(['Hate','Not-Hate']), index = np.array(['Hate','Not-Hate']))
df_cm.index.name = 'Actual Label'
df_cm.columns.name = 'Predicted Label' 
plt.figure(figsize = (7,7),dpi=100)
sn.set(font_scale=1.5)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True)# font size
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-135f7dd05aca> in <module>
#      13 sn.set(font_scale=1.5)#for label size
#      14 sn.heatmap(df_cm, cmap="Blues", annot=True)# font size
# ---> 15 bottom, top = ax.get_ylim()
#      16 ax.set_ylim(bottom + 0.5, top - 0.5)
#
# NameError: name 'ax' is not defined

# %%
df_cm
# Out:
# Predicted Label  Hate  Not-Hate
# Actual Label
# Hate             1993       127
# Not-Hate          173      2707

# %%
np.unique(y_true)
# Out:
# array(['chevrolet', 'honda', 'toyota'], dtype='<U9')

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

y_true = ["honda", "chevrolet", "honda", "toyota", "toyota", "chevrolet"]
y_pred = ["honda", "chevrolet", "honda", "toyota", "toyota", "honda"]
data = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(data, columns=np.unique(y_true), index = np.unique(y_true))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 16})# font size

# %%
import pandas as pd
df=pd.read_csv('wm.csv')

# %%
df=df[['0','1','2']]

# %%
df
# Out:
#                0                                                  1  \
# 0      strenuous  {'Adjective': ['characterized by or performed ...
# 1           zeal  {'Noun': ['a feeling of strong eagerness (usua...
# 2       surmount  {'Verb': ['get on top of; deal with successful...
# 3        froward  {'Adjective': ['habitually disposed to disobed...
# 4         baying  {'Verb': ['utter in deep prolonged tones', 'ba...
# ...          ...                                                ...
# 2812     epithet  {'Noun': ['a defamatory or abusive word or phr...
# 2813        yoke  {'Noun': ['fabric comprising a fitted part at ...
# 2814  consummate  {'Verb': ['fulfill sexually', 'make perfect; b...
# 2815        smug  {'Adjective': ['marked by excessive complacenc...
# 2816  peripheral  {'Noun': ['electronic equipment external to th...
#
#                                                       2
# 0                                         ['energetic']
# ...

# %%
df.columns = ['Word','Meaning','Synonym']

# %%
df
# Out:
#             Word                                            Meaning  \
# 0      strenuous  {'Adjective': ['characterized by or performed ...
# 1           zeal  {'Noun': ['a feeling of strong eagerness (usua...
# 2       surmount  {'Verb': ['get on top of; deal with successful...
# 3        froward  {'Adjective': ['habitually disposed to disobed...
# 4         baying  {'Verb': ['utter in deep prolonged tones', 'ba...
# ...          ...                                                ...
# 2812     epithet  {'Noun': ['a defamatory or abusive word or phr...
# 2813        yoke  {'Noun': ['fabric comprising a fitted part at ...
# 2814  consummate  {'Verb': ['fulfill sexually', 'make perfect; b...
# 2815        smug  {'Adjective': ['marked by excessive complacenc...
# 2816  peripheral  {'Noun': ['electronic equipment external to th...
#
#                                                 Synonym
# 0                                         ['energetic']
# ...

# %%
df.to_json('words.json',index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-c6ab538667bb> in <module>
# ----> 1 df.to_json('words.json',index=False)
#
# c:\users\bharg\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent)
#    2303             compression=compression,
#    2304             index=index,
# -> 2305             indent=indent,
#    2306         )
#    2307
#
# c:\users\bharg\appdata\local\programs\python\python36\lib\site-packages\pandas\io\json\_json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent)
#      49     if not index and orient not in ["split", "table"]:
#      50         raise ValueError(
# ...
